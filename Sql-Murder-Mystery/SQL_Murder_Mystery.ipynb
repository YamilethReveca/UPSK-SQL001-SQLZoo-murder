# %% [markdown]
# <a href="https://colab.research.google.com/github/icarito/UPSK-SQL001-SQLZoo-murder/blob/sql-murder/Sql-Murder-Mystery/SQL_Murder_Mystery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL Murder Mystery!
# Adapted By: Martin Arroyo
#
# ![Detective making connections between points](https://github.com/freestackinitiative/coop_sql_notebooks/blob/main/assets/sleuth.png?raw=1)
#
# **Credit**
#
# This material was adapted from the [SQL Murder Mystery by Knight Lab](https://mystery.knightlab.com/) under [Creative Commons CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/). The SQL Murder Mystery was originally created by [Joon Park](https://twitter.com/joonparkmusic) and [Cathy He](https://twitter.com/Cathy_MeiyingHe) while they were Knight Lab fellows. See the [GitHub repository](https://github.com/NUKnightLab/sql-mysteries) for more information.

# %% [markdown]
# ## Escenario
#
# ¡Se ha cometido un crimen y los detectives necesitan tu ayuda! Te dieron el informe de la escena del crimen, pero de alguna manera lo perdiste. Recuerdas vagamente que el crimen fue un `murder` _(asesinato)_ que ocurrió en algún momento el 15 de Enero de 2018 y que tuvo lugar en `SQL City`. Depende de ti averiguar quién es el asesino usando solo tus habilidades en SQL y tu ingenio. Te proporcionan una conexión a la base de datos del Departamento de Policía, que tiene todas las pistas que necesitarás para atrapar al asesino.
#
# Usa las habilidades que desarrollaste en SQL 101 y 102, junto con cualquier recurso que desees, para resolver el `SQL Murder Mystery`!"

# %% [markdown]
# ## Conéctate a la base de datos del Departamento de Policía
#
# Para comenzar y ejecutar tus consultas, presiona play en la celda de abajo para conectarte a la base de datos del Departamento de Policía.
#
# Para ejecutar consultas, crea una nueva celda de `Code` y escribe `%%sql` en la parte superior. Luego puedes escribir tus consultas debajo. Ve el ejemplo a continuación:
# ```python
# %%sql
#
# SELECT *
# FROM table
#
# ```

# %%
# %%capture
# @title Press Play { display-mode: "form" }
# Install `teachdb` and `coop_grader`
print("Installing `teachdb` and its dependencies...")
# !pip install --quiet --upgrade git+https://github.com/freestackinitiative/teachingdb.git git+https://github.com/martinmarroyo/coop_grader.git
print("Successfully installed `teachdb`")
import pandas as pd
from teachdb.teachdb import connect_teachdb
from coop_grader.sql_murder_mystery.check_suspect import check_suspect
# Set configurations for notebook
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 99)
# Load data
con = connect_teachdb(database="sql_murder_mystery")

# %sql con

# %% [markdown]
# ## Descubriendo tablas en la base de datos
#
# Comenzamos nuestra búsqueda para encontrar al asesino explorando la base de datos del Departamento de Policía. Pero aún no has visto la base de datos y no sabes cuáles son las tablas, así que, ¿cómo sabes qué buscar?
#
# Afortunadamente, la mayoría de los sistemas de gestión de bases de datos relacionales tienen esta información almacenada en un lugar donde puedes consultarla. Muy a menudo, se utiliza un esquema especial conocido como [`information_schema`](https://en.wikipedia.org/wiki/Information_schema) para almacenar información sobre las tablas y columnas en tu base de datos (también conocido como metadata). La base de datos del Departamento de Policía tiene un information schema, con la vista `tables` que te muestra qué tablas están disponibles, y la vista `columns` que te muestra todas las columnas de cada tabla y sus tipos de datos.

# %% [markdown]
# ### Listando todas las tablas en la base de datos de la Policía
#
# #### Revisa la [descripción de `information_schema.tables`](https://duckdb.org/docs/sql/information_schema.html#tables-and-views)
#
# Primero, veremos todas las tablas disponibles para nosotros consultando la vista `information_schema.tables`. Te daremos la primera consulta para empezar, pero de aquí en adelante tendrás que idear las consultas restantes utilizando tu conocimiento de SQL y tu ingenio.
#
# Aquí está la consulta necesaria para mostrarte las tablas en la base de datos del Departamento de Policía. Cópiala/Pégala en la celda de abajo y ejecútala para ver las tablas disponibles para ti:
#
# >```sql
# >SELECT *
# >FROM information_schema.tables
# >```

# %%
# %%sql
# SELECT *
# FROM information_schema.tables
# Out:
#   table_catalog table_schema              table_name  table_type  \
# 0        memory         main      crime_scene_report  BASE TABLE
# 1        memory         main         drivers_license  BASE TABLE
# 2        memory         main  facebook_event_checkin  BASE TABLE
# 3        memory         main    get_fit_now_check_in  BASE TABLE
# 4        memory         main      get_fit_now_member  BASE TABLE
# 5        memory         main                  income  BASE TABLE
# 6        memory         main               interview  BASE TABLE
# 7        memory         main                  person  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
#
#   commit_action TABLE_COMMENT
# 0          None          None
# 1          None          None
# 2          None          None
# 3          None          None
# 4          None          None
# 5          None          None
# 6          None          None
# 7          None          None

# %% [markdown]
# ### Listando todas las tablas y sus columnas en la base de datos de la Policía
#
# **Revisa la [descripción de `information_schema.columns`](https://duckdb.org/docs/sql/information_schema.html#columns)**
#
# ¡Genial! Ahora que sabes qué tablas están disponibles, es hora de averiguar las columnas que tiene cada tabla junto con el tipo de datos de cada columna. Escribe una consulta que muestre el nombre de la tabla, el nombre de la columna y el tipo de datos para cada tabla en la base de datos del Departamento de Policía utilizando la vista `information_schema.columns`. Asegúrate de que la salida esté ordenada por nombre de tabla y luego por nombre de columna (ascendente):
#
# *Pistas opcionales - ¡intenta usarlas solo si te quedas **REALMENTE** atascado!*
#
# <details>
# <summary>Pista 1</summary>
# <p>Estructura tu consulta de la misma manera que lo hicimos en la consulta anterior donde miramos `information_schema.tables`</p>
# </details>
#
# <details>
# <summary>Pista 2</summary>
# <p>Asegúrate de revisar el enlace para la descripción de information_schema.columns. Te dirá los nombres de las columnas que debes usar para la consulta. Recuerda, queremos el nombre de la tabla, el nombre de la columna y el tipo de datos - ¡revisa la descripción para encontrar los nombres apropiados!</p>
# </details>
#
# <details>
# <summary>Pista 3</summary>
# <p>No olvides usar la declaración ORDER BY para ordenar los resultados de tu búsqueda. Estamos buscando ordenar ambas columnas en orden ascendente, lo cual se puede especificar usando la palabra clave ASC, sin embargo, también es el orden de clasificación predeterminado, por lo que ASC no es necesariamente requerido.</p>
# </details>

# %%
# %%sql
# SELECT *
# FROM crime_scene_report
# Out:
#           date       type  \
# 0     20180115    robbery
# 1     20180115     murder
# 2     20180115     murder
# 3     20180215     murder
# 4     20180215     murder
# 5     20180115      theft
# 6     20180115      fraud
# 7     20170712      theft
# 8     20170820      arson
# 9     20171110    robbery
# 10    20180103    bribery
# 11    20180115    assault
# 12    20180115    assault
# 13    20170101      fraud
# 14    20170101      fraud
# 15    20170101      theft
# 16    20170101  smuggling
# 17    20170101    assault
# 18    20170102      arson
# 19    20170102    bribery
# 20    20170102      theft
# 21    20170102  smuggling
# 22    20170103      arson
# 23    20170104  blackmail
# 24    20170105      theft
# 25    20170105    robbery
# 26    20170106  blackmail
# 27    20170106  blackmail
# 28    20170106      theft
# 29    20170107    bribery
# 30    20170107  smuggling
# 31    20170107  blackmail
# 32    20170107      theft
# 33    20170107     murder
# 34    20170108     murder
# 35    20170108      theft
# 36    20170108     murder
# 37    20170109    robbery
# 38    20170109      fraud
# 39    20170109      arson
# 40    20170109      arson
# 41    20170109    bribery
# 42    20170110  blackmail
# 43    20170111     murder
# 44    20170111    bribery
# 45    20170112  smuggling
# 46    20170113      fraud
# 47    20170113  blackmail
# 48    20170113    assault
# 49    20170114      fraud
# 50    20170114  blackmail
# 51    20170114      fraud
# 52    20170115    assault
# 53    20170115      theft
# 54    20170115    robbery
# 55    20170116  blackmail
# 56    20170116    assault
# 57    20170116  blackmail
# 58    20170116    bribery
# 59    20170116  smuggling
# 60    20170117    assault
# 61    20170117    bribery
# 62    20170118    robbery
# 63    20170118      arson
# 64    20170118      theft
# 65    20170119  smuggling
# 66    20170119    robbery
# 67    20170121      arson
# 68    20170121     murder
# 69    20170122    robbery
# 70    20170122    bribery
# 71    20170122    bribery
# 72    20170122     murder
# 73    20170122    assault
# 74    20170123  blackmail
# 75    20170123    assault
# 76    20170124      arson
# 77    20170124     murder
# 78    20170124    robbery
# 79    20170124     murder
# 80    20170125     murder
# 81    20170125      theft
# 82    20170126      arson
# 83    20170127      arson
# 84    20170127  blackmail
# 85    20170128      theft
# 86    20170128      theft
# 87    20170128    assault
# 88    20170129      arson
# 89    20170129    bribery
# 90    20170129  blackmail
# 91    20170129    robbery
# 92    20170129    assault
# 93    20170130      fraud
# 94    20170130      arson
# 95    20170130      fraud
# 96    20170131    bribery
# 97    20170131    bribery
# 98    20170131    bribery
# 99    20170201      fraud
# 100   20170202  blackmail
# 101   20170202    robbery
# 102   20170202  smuggling
# 103   20170202  smuggling
# 104   20170203      arson
# 105   20170203  smuggling
# 106   20170204  blackmail
# 107   20170204      theft
# 108   20170205    robbery
# 109   20170205    robbery
# 110   20170205  smuggling
# 111   20170205    bribery
# 112   20170205      fraud
# 113   20170207      arson
# 114   20170207     murder
# 115   20170207      arson
# 116   20170208      theft
# 117   20170208      fraud
# 118   20170208      fraud
# 119   20170208  smuggling
# 120   20170209  smuggling
# 121   20170209  smuggling
# 122   20170210    assault
# 123   20170210      arson
# 124   20170210  blackmail
# 125   20170210    bribery
# 126   20170211      arson
# 127   20170212      fraud
# 128   20170212    assault
# 129   20170212    robbery
# 130   20170212    bribery
# 131   20170214      fraud
# 132   20170214      fraud
# 133   20170214    assault
# 134   20170214    bribery
# 135   20170215      arson
# 136   20170215      theft
# 137   20170215      arson
# 270   20170409      arson
# 271   20170409     murder
# 272   20170409    bribery
# 273   20170410  smuggling
# 274   20170410    assault
# 275   20170411      fraud
# 276   20170411  smuggling
# 277   20170411  blackmail
# 278   20170412    robbery
# 279   20170412  smuggling
# 280   20170412      arson
# 281   20170412      arson
# 282   20170413    bribery
# 283   20170413    bribery
# 284   20170414      arson
# 285   20170414  smuggling
# 286   20170414    assault
# 287   20170415    bribery
# 288   20170415      theft
# 289   20170415  blackmail
# 290   20170415    bribery
# 291   20170416  smuggling
# 292   20170416      theft
# 293   20170416      fraud
# 294   20170417     murder
# 295   20170418      theft
# 296   20170419  smuggling
# 297   20170419      fraud
# 298   20170420     murder
# 299   20170420    bribery
# 300   20170420      arson
# 301   20170420    assault
# 302   20170421    bribery
# 303   20170421  smuggling
# 304   20170421    bribery
# 305   20170422      arson
# 306   20170424     murder
# 307   20170425    bribery
# 308   20170425      arson
# 309   20170425     murder
# 310   20170425      fraud
# 311   20170426  smuggling
# 312   20170426    bribery
# 313   20170426      arson
# 314   20170427      theft
# 315   20170427      theft
# 316   20170428      theft
# 317   20170428      fraud
# 318   20170428  smuggling
# 319   20170428      arson
# 320   20170429     murder
# 321   20170429    bribery
# 322   20170429      theft
# 323   20170430    assault
# 324   20170430    bribery
# 325   20170430    robbery
# 326   20170430      fraud
# 327   20170430      fraud
# 328   20170501  smuggling
# 329   20170502     murder
# 330   20170502      arson
# 331   20170502    robbery
# 332   20170503    assault
# 333   20170503      theft
# 334   20170504  blackmail
# 335   20170504    assault
# 336   20170504    assault
# 337   20170505    bribery
# 338   20170506      arson
# 339   20170506      arson
# 340   20170507    bribery
# 341   20170507      theft
# 342   20170508      arson
# 343   20170508    assault
# 344   20170508      fraud
# 345   20170509  blackmail
# 346   20170509      arson
# 347   20170509    robbery
# 348   20170509    robbery
# 349   20170509      theft
# 350   20170510    robbery
# 351   20170511  blackmail
# 352   20170511      fraud
# 353   20170511  smuggling
# 354   20170512    assault
# 355   20170512  smuggling
# 356   20170513     murder
# 357   20170513  smuggling
# 358   20170513     murder
# 359   20170513  blackmail
# 360   20170515  smuggling
# 361   20170515    bribery
# 362   20170515      arson
# 363   20170516      theft
# 364   20170517    bribery
# 365   20170518    assault
# 366   20170518  smuggling
# 367   20170518  smuggling
# 368   20170518  blackmail
# 369   20170519    robbery
# 370   20170519     murder
# 371   20170519    bribery
# 372   20170520    robbery
# 373   20170520      fraud
# 374   20170520      theft
# 375   20170520  blackmail
# 376   20170522    bribery
# 377   20170523    assault
# 378   20170524    assault
# 379   20170524  blackmail
# 380   20170525    bribery
# 381   20170525    robbery
# 382   20170525  blackmail
# 383   20170526    robbery
# 384   20170526    assault
# 385   20170527      fraud
# 386   20170527      arson
# 387   20170527      arson
# 388   20170527      arson
# 389   20170527      theft
# 390   20170528    assault
# 391   20170528    bribery
# 392   20170528  smuggling
# 393   20170529    assault
# 394   20170529      fraud
# 395   20170529  smuggling
# 396   20170529    robbery
# 397   20170529    assault
# 398   20170530      arson
# 399   20170530    assault
# 400   20170530      arson
# 401   20170602  blackmail
# 402   20170602      fraud
# 403   20170602    robbery
# 404   20170602      fraud
# 405   20170603  blackmail
# 406   20170604    assault
# 407   20170604      fraud
# 408   20170604     murder
# 409   20170604    bribery
# 410   20170604      arson
# 411   20170606    assault
# 412   20170606    bribery
# 413   20170606      fraud
# 414   20170606    bribery
# 415   20170606    assault
# 416   20170607    bribery
# 417   20170607     murder
# 418   20170607  smuggling
# 419   20170609    assault
# 420   20170609     murder
# 421   20170609     murder
# 422   20170609      theft
# 423   20170610      theft
# 424   20170610  smuggling
# 425   20170610    bribery
# 426   20170610    bribery
# 427   20170611      arson
# 428   20170611      arson
# 429   20170611     murder
# 430   20170612     murder
# 431   20170613      theft
# 432   20170613      arson
# 433   20170614    robbery
# 434   20170614      theft
# 435   20170614    robbery
# 436   20170614      fraud
# 437   20170615    robbery
# 438   20170615  blackmail
# 439   20170615    assault
# 440   20170615      fraud
# 441   20170617  smuggling
# 442   20170617    robbery
# 443   20170617      arson
# 444   20170618  blackmail
# 445   20170618  smuggling
# 446   20170618      theft
# 447   20170618    bribery
# 448   20170619    assault
# 449   20170620      arson
# 450   20170620    bribery
# 451   20170620    robbery
# 452   20170620    robbery
# 453   20170621      arson
# 454   20170621    robbery
# 455   20170621      fraud
# 456   20170621     murder
# 457   20170622  blackmail
# 458   20170622      arson
# 459   20170622  blackmail
# 460   20170623    assault
# 461   20170623      theft
# 462   20170624    assault
# 463   20170624    bribery
# 464   20170624  smuggling
# 465   20170624      fraud
# 466   20170624      fraud
# 467   20170625      fraud
# 468   20170625      fraud
# 469   20170625    assault
# 470   20170625    bribery
# 471   20170625      arson
# 472   20170626      arson
# 473   20170626    robbery
# 474   20170626    robbery
# 475   20170626    robbery
# 476   20170627      theft
# 477   20170627      fraud
# 478   20170627    bribery
# 479   20170627  smuggling
# 480   20170628  smuggling
# 481   20170628    robbery
# 482   20170628    robbery
# 483   20170628    assault
# 484   20170628      arson
# 485   20170629      theft
# 486   20170629  smuggling
# 487   20170629  smuggling
# 488   20170629      theft
# 489   20170630  smuggling
# 490   20170702    assault
# 491   20170702  blackmail
# 492   20170704     murder
# 493   20170704      arson
# 494   20170704      theft
# 495   20170704     murder
# 496   20170705  blackmail
# 497   20170705     murder
# 498   20170705      theft
# 499   20170706      arson
# 500   20170706    bribery
# 501   20170706  smuggling
# 502   20170706     murder
# 503   20170707    assault
# 504   20170707      fraud
# 505   20170707     murder
# 506   20170707      fraud
# 507   20170708    robbery
# 508   20170708     murder
# 509   20170708  smuggling
# 510   20170709    bribery
# 511   20170709      fraud
# 512   20170709  blackmail
# 513   20170709      fraud
# 514   20170709    robbery
# 515   20170710    assault
# 516   20170710    assault
# 517   20170710      arson
# 518   20170713    assault
# 519   20170713      theft
# 520   20170713  blackmail
# 521   20170713  blackmail
# 522   20170713      fraud
# 523   20170714    assault
# 524   20170715      fraud
# 525   20170715    bribery
# 526   20170715    assault
# 527   20170715  smuggling
# 528   20170716     murder
# 529   20170720     murder
# 530   20170720      theft
# 663   20170918  smuggling
# 664   20170918  blackmail
# 665   20170918      theft
# 666   20170918    bribery
# 667   20170919      theft
# 668   20170919    robbery
# 669   20170919      fraud
# 670   20170919    bribery
# 671   20170920    robbery
# 672   20170920      theft
# 673   20170921     murder
# 674   20170921      fraud
# 675   20170921  blackmail
# 676   20170921  blackmail
# 677   20170921  blackmail
# 678   20170922  smuggling
# 679   20170922    assault
# 680   20170922    assault
# 681   20170922    assault
# 682   20170925    bribery
# 683   20170926    bribery
# 684   20170926  smuggling
# 685   20170926    robbery
# 686   20170926     murder
# 687   20170926      arson
# 688   20170927    robbery
# 689   20170927      fraud
# 690   20170927    assault
# 691   20170927  smuggling
# 692   20170927  blackmail
# 693   20170928    robbery
# 694   20170928    robbery
# 695   20170928  blackmail
# 696   20170929     murder
# 697   20170930  blackmail
# 698   20170930      arson
# 699   20170930    bribery
# 700   20171002  blackmail
# 701   20171002     murder
# 702   20171002    bribery
# 703   20171002      fraud
# 704   20171002      theft
# 705   20171003     murder
# 706   20171004  smuggling
# 707   20171004    assault
# 708   20171004  smuggling
# 709   20171004    assault
# 710   20171005     murder
# 711   20171005    bribery
# 712   20171006    bribery
# 713   20171007  blackmail
# 714   20171009    robbery
# 715   20171009      fraud
# 716   20171009    bribery
# 717   20171010     murder
# 718   20171010  smuggling
# 719   20171010  smuggling
# 720   20171012    bribery
# 721   20171012      arson
# 722   20171012      theft
# 723   20171012      arson
# 724   20171012     murder
# 725   20171013      arson
# 726   20171013    bribery
# 727   20171013      fraud
# 728   20171013     murder
# 729   20171013     murder
# 730   20171014    bribery
# 731   20171015     murder
# 732   20171015     murder
# 733   20171015      arson
# 734   20171015    robbery
# 735   20171016      theft
# 736   20171016     murder
# 737   20171016     murder
# 738   20171017    bribery
# 739   20171017     murder
# 740   20171017    bribery
# 741   20171017  blackmail
# 742   20171018  blackmail
# 743   20171018      fraud
# 744   20171018     murder
# 745   20171018    robbery
# 746   20171019      theft
# 747   20171019      theft
# 748   20171020    bribery
# 749   20171020      theft
# 750   20171021    bribery
# 751   20171021     murder
# 752   20171022  blackmail
# 753   20171023      theft
# 754   20171023    bribery
# 755   20171023     murder
# 756   20171023      fraud
# 757   20171023  smuggling
# 758   20171024     murder
# 759   20171024  smuggling
# 760   20171024      theft
# 761   20171025      arson
# 762   20171025    assault
# 763   20171025      arson
# 764   20171027      arson
# 765   20171027     murder
# 766   20171027    robbery
# 767   20171027      fraud
# 768   20171028      arson
# 769   20171028    bribery
# 770   20171028    assault
# 771   20171029     murder
# 772   20171029    assault
# 773   20171029    robbery
# 774   20171031      arson
# 775   20171101    assault
# 776   20171101  smuggling
# 777   20171101    assault
# 778   20171102  smuggling
# 779   20171102    bribery
# 780   20171103     murder
# 781   20171104      fraud
# 782   20171105  smuggling
# 783   20171105      arson
# 784   20171105      fraud
# 785   20171105    bribery
# 786   20171106    robbery
# 787   20171106     murder
# 788   20171106    assault
# 789   20171107  blackmail
# 790   20171107    assault
# 791   20171107     murder
# 792   20171107      arson
# 793   20171107  blackmail
# 26                              rather sharply; ‘I advise you to leave off this minute!’ She generally\n
# 27                                                                    CHAPTER X. The Lobster Quadrille\n
# 28                                   ‘Of course it is,’ said the Duchess, who seemed ready to agree to\n
# 29                             The hedgehog was engaged in a fight with another hedgehog, which seemed\n
# 30                                                                                                    \n
# 31                             This answer so confused poor Alice, that she let the Dormouse go on for\n
# 32                               felt certain it must be really offended. ‘We won’t talk about her any\n
# 33                              ‘It proves nothing of the sort!’ said Alice. ‘Why, you don’t even know\n
# 34                                                     get” is the same thing as “I get what I like”!’\n
# 35                                  Alice tried to fancy to herself what such an extraordinary ways of\n
# 36                                                                                          HEARTHRUG,\n
# 37                                 finished, her sister kissed her, and said, ‘It WAS a curious dream,\n
# 38                             his fan and gloves--that is, if I can find them.’ As she said this, she\n
# 39                               mouth; but she did it at last, and managed to swallow a morsel of the\n
# 40                              for the next moment a shower of little pebbles came rattling in at the\n
# 41                                                                                             condemn\n
# 42                              Alice was not much surprised at this, she was getting so used to queer\n
# 43                                                                                                    \n
# 44                                                          (In which the cook and the baby joined):--\n
# 45                                                                                                    \n
# 46                            Dinah, and saying to her very earnestly, ‘Now, Dinah, tell me the truth:\n
# 47                               ‘There’s no sort of use in knocking,’ said the Footman, ‘and that for\n
# 48                                                                                                    \n
# 49                                   ‘Off with their heads!’ and the procession moved on, three of the\n
# 50                                                                                                    \n
# 51                               ‘I couldn’t afford to learn it.’ said the Mock Turtle with a sigh. ‘I\n
# 52                                                             ‘Nothing WHATEVER?’ persisted the King.\n
# 53                             The Knave shook his head sadly. ‘Do I look like it?’ he said. (Which he\n
# 54                               think,’ Alice went on, ‘that they’d let Dinah stop in the house if it\n
# 55                                                                                                    \n
# 56                                 my fur and whiskers! She’ll get me executed, as sure as ferrets are\n
# 57                             Fish-Footman was gone, and the other was sitting on the ground near the\n
# 58                                                                                                    \n
# 59                             living would be like, but it puzzled her too much, so she went on: ‘But\n
# 60                              with the words ‘DRINK ME,’ but nevertheless she uncorked it and put it\n
# 61                             you liked with the clock. For instance, suppose it were nine o’clock in\n
# 62                             the pool, and the great hall, with the glass table and the little door,\n
# 63                             minute or two, which gave the Pigeon the opportunity of adding, ‘You’re\n
# 64                                                                                                on.’\n
# 65                                                                                        and sadly:--\n
# 66                                                                                                    \n
# 67                              voice, ‘Why the fact is, you see, Miss, this here ought to have been a\n
# 68                                                                         her, to pass away the time.\n
# 69                                                                                                    \n
# 70                                                                                                    \n
# 71                                                                                                    \n
# 72                             came near her, she began, in a low, timid voice, ‘If you please, sir--’\n
# 73                                                                                                    \n
# 74                                                                                                    \n
# 75                                                                                                    \n
# 76                                                                                                    \n
# 77                                about something, my dear, and that makes you forget to talk. I can’t\n
# 78                                     a little shriek, and went on: ‘--that begins with an M, such as\n
# 79                                                                                                    \n
# 80                              age knew the meaning of it at all. However, ‘jury-men’ would have done\n
# 81                                                 ‘Can’t remember WHAT things?’ said the Caterpillar.\n
# 82                                                                              ‘I won’t!’ said Alice.\n
# 83                              tried to get her head down to them, and was delighted to find that her\n
# 84                             thousand miles down, I think--’ (for, you see, Alice had learnt several\n
# 85                                                                  ‘--as far out to sea as you can--’\n
# 86                                                          ‘The Queen of Hearts, she made some tarts,\n
# 87                                                     wag my tail when I’m angry. Therefore I’m mad.’\n
# 88                               of things--I can’t remember half of them--and it belongs to a farmer,\n
# 89                                   ‘I’m sure I’m not Ada,’ she said, ‘for her hair goes in such long\n
# 90                            ‘Call the first witness,’ said the King; and the White Rabbit blew three\n
# 91                                                                                                    \n
# 92                                 OUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,\n
# 93                                                                                                    \n
# 94                                                                                                    \n
# 95                                                                                             a bit.’\n
# 96                                                                                                    \n
# 97                                                                                                    \n
# 98                                                                                         every line:\n
# 99                                                                                       close by her.\n
# 100                                                                                                   \n
# 101                            four times seven is--oh dear! I shall never get to twenty at that rate!\n
# 102                            She was a good deal frightened by this very sudden change, but she felt\n
# 103                            (she was obliged to say ‘creatures,’ you see, because some of them were\n
# 104                            occasional exclamation of ‘Hjckrrh!’ from the Gryphon, and the constant\n
# 105                                                                                                   \n
# 106                                                                                                   \n
# 107                                                                                                   \n
# 108                             The next witness was the Duchess’s cook. She carried the pepper-box in\n
# 109                              ‘This here young lady,’ said the Gryphon, ‘she wants for to know your\n
# 110                              would change to dull reality--the grass would be only rustling in the\n
# 111                                                                                                   \n
# 112                             with the words ‘DRINK ME,’ but nevertheless she uncorked it and put it\n
# ...
# 613             Hayward
# 614      Virginia Beach
# 615           Lancaster
# 616           Kalamazoo
# 617           Elizabeth
# 618        Murfreesboro
# 619              Dallas
# 620          Long Beach
# 621          Cape Coral
# 622          Youngstown
# 623            Billings
# 624          Las Cruces
# 625              Canton
# 626              Yakima
# 627              Dallas
# 628       Santa Clarita
# 629              Aurora
# 630            Chandler
# 631            Honolulu
# 632            Gastonia
# 633         Panama City
# 634          Springdale
# 635              Duluth
# 636               Lacey
# 637           Fullerton
# 638              Corona
# 639           Grayslake
# 640               Provo
# 641              Oxnard
# 642          Scottsdale
# 643           Worcester
# 644          Sioux City
# 645       Clarke County
# 646          Cincinnati
# 647             McHenry
# 648             Memphis
# 649           St. Louis
# 650          High Point
# 651             Detroit
# 652             Atlanta
# 653           Kissimmee
# 654           Kissimmee
# 655           Henderson
# 656               Houma
# 657             Visalia
# 658              Pueblo
# 659             McHenry
# 660         Port Arthur
# 661           Melbourne
# 662         Bloomington
# 663             Winston
# 664              Toledo
# 665        Fayetteville
# 666             Gilbert
# 667            Amarillo
# 668          Bridgeport
# 669           Bradenton
# 670            Rockford
# 671          Wilmington
# 672             Trenton
# 673          South Bend
# 674           Bremerton
# 675         Tallahassee
# 676         Minneapolis
# 677             Phoenix
# 678           Hollywood
# 679          Hagerstown
# 680            St. Paul
# 681              Tucson
# 682         Bloomington
# 683           Davenport
# 684             Jackson
# 685             Phoenix
# 686      Cathedral City
# 687              Warren
# 688              Marina
# 689               Macon
# 690            Murrieta
# 691          Clearwater
# 692              Fresno
# 693     Richmond County
# 694         Springfield
# 695              Canton
# 696            Hartford
# 697             Garland
# 698          Sioux City
# 699           Santa Ana
# 700               Lacey
# 701            Glendale
# 702               Tampa
# 703       Thousand Oaks
# 704                Mesa
# 705         Punta Gorda
# 706            Lakewood
# 707    Sterling Heights
# 708              Norman
# 709             Detroit
# 710          Cape Coral
# 711              Durham
# 712            Rockford
# 713          Fort Smith
# 714        Lake Charles
# 715           Inglewood
# 716            Waterloo
# 717        Cedar Rapids
# 718         Jersey City
# 719        Cedar Rapids
# 720               Akron
# 721             Norwalk
# 722              Layton
# 723              Aurora
# 724           Davenport
# 725             Antioch
# 726         West Covina
# 727          Evansville
# 728              Nashua
# 729            Stockton
# 730         New Orleans
# 731              Eugene
# 732              Austin
# 733             Lubbock
# 734          Washington
# 735      Havre de Grace
# 736             Modesto
# 737              Odessa
# 738           Kalamazoo
# 739         Bakersfield
# 740             Atlanta
# 741        Cedar Rapids
# 742         Chattanooga
# 743          Sioux City
# 744             Antioch
# 745       Daytona Beach
# 746              Aurora
# 747         Minneapolis
# 748           Waterbury
# 749          Harrisburg
# 750          Huntington
# 751            Billings
# 752           Bradenton
# 753            GreenBay
# 754          Evansville
# 755    Round Lake Beach
# 756          Santa Cruz
# 757        Murfreesboro
# 758            Rockford
# 759                Orem
# 760         Clarksville
# 761           Daly City
# 762          Providence
# 763         Port Arthur
# 764           Cambridge
# 765          Youngstown
# 766           Waterbury
# 767            San Jose
# 768              Yakima
# 769         Jersey City
# 770              Peoria
# 771          Washington
# 772          Hagerstown
# 773        Murfreesboro
# 774             Lubbock
# 775              Oxnard
# 776             Yonkers
# 777            Mesquite
# 778          Chesapeake
# 779       Santa Clarita
# 780          Vero Beach
# 781        Fort Collins
# 782        Fort Collins
# 783        Fayetteville
# 784    Port Saint Lucie
# 785          New London
# 786        Myrtle Beach
# 787          Charleston
# 788       Oklahoma City
# 789            Berkeley
# 790             Augusta
# 791             Concord
# 792              Tucson
# 793          Clearwater
# 794      Corpus Christi
# 795            Rockford
# 796             Yonkers
# 797         Clarksville
# 798           Waterbury
# 799         Jersey City
# 800              Denver
# 801            Richmond
# 802      Virginia Beach
# 803              Olathe
# 804         Little Rock
# 805       Clarke County
# 806             Hialeah
# 807              Downey
# 808               Flint
# 809              Oxnard
# 810          Long Beach
# 811           Inglewood
# 812           Elk Grove
# 813             Norwalk
# 814             Kenosha
# 815          Fort Smith
# 816         Jersey City
# 817              Durham
# 818          Harrisburg
# 819         San Antonio
# 820          Springdale
# 821              Athens
# 822         Little Rock
# 823        Winter Haven
# 824          Sacramento
# 825            St. Paul
# 826       New York City
# 827            Paterson
# 828       New York City
# 829             Killeen
# 830        Fayetteville
# 831             Madison
# 832           Kalamazoo
# 833           Sunnyvale
# 834              Pomona
# 835         Westminster
# 836            Appleton
# 837               Ocala
# 838               Ocala
# 839             Seattle
# 840          Wilmington
# 841         Sioux Falls
# 842               Akron
# 843              Monroe
# 844         Port Orange
# 845               Hemet
# 846               Salem
# 847           Hollywood
# 848        Cedar Rapids
# 849         Bakersfield
# 850             Chicago
# 851          Sacramento
# 852             Miramar
# 853       Santa Clarita
# 854           Ann Arbor
# 855          Huntington
# 856              Topeka
# 857          Providence
# 858          Lewisville
# 859              Dallas
# 860    Saint Petersburg
# 861             Hayward
# 862           Baltimore
# 863             Salinas
# 864          Youngstown
# 865          Tuscaloosa
# 866              Yakima
# 867          Springdale
# 868              Peoria
# 869             Killeen
# 870          Carrollton
# 871          Greensboro
# 872          Fort Wayne
# 873              Irving
# 874            Richmond
# 875          Providence
# 876            Scranton
# 877           Lexington
# 878              Aurora
# 879            Scranton
# 880              Toledo
# 881          Vero Beach
# 882              Norman
# 883           Fairfield
# 884           Baltimore
# 885          Santa Cruz
# 886             Visalia
# 887     Gulfport-Biloxi
# 888              Athens
# 889         Baton Rouge
# 890              Odessa
# 891           Nashville
# 892           Cleveland
# 893         Chula Vista
# 894    Round Lake Beach
# 895              Pueblo
# 896             Orlando
# 897              Corona
# 898    North Charleston
# 899     Richmond County
# 900              Boston
# 901             Orlando
# 902             McAllen
# 903               Fargo
# 904        Newport News
# 905              Marina
# 906           Harlingen
# 907   Fort Walton Beach
# 908           Kissimmee
# 909              Nashua
# 910              Merced
# 911        Palm Springs
# 912              Lorain
# 913       Coral Springs
# 914           Las Vegas
# 915           Escondido
# 916             Roanoke
# 917               Akron
# 918       Pompano Beach
# 919            St. Paul
# 920         Chattanooga
# 921             Norfolk
# 922             Chicago
# 923             Raleigh
# 924               Tempe
# 925             Antioch
# 926             Spokane
# 927         West Covina
# 928            Glendale
# 929    Huntington Beach
# 930            Honolulu
# 931             Yonkers
# 932              Pomona
# 933           Frederick
# 934             Houston
# 935          Las Cruces
# 936     Fort Lauderdale
# 937                Reno
# 938            Lakeland
# 939      Cathedral City
# 940              Canton
# 941            Scranton
# 942          Sioux City
# 943           Cambridge
# 944             Orlando
# 945          Wilmington
# 946               Utica
# 947               Tempe
# 948           Ann Arbor
# 949    Saint Petersburg
# 950         New Bedford
# 951         Chattanooga
# 952          Evansville
# 953           St. Louis
# 954          Charleston
# 955               Flint
# 956             Hialeah
# 957          Barnstable
# 958      Corpus Christi
# 959           Harlingen
# 960       San Francisco
# 961      Bonita Springs
# 962             Danbury
# 963          Portsmouth
# 964            Sarasota
# 965            Stamford
# 966             Lincoln
# 967            Beaumont
# 968           Lancaster
# 969         Kansas City
# 970        Philadelphia
# 971                Reno
# 972    San Buenaventura
# 973          Marysville
# 974              Yakima
# 975               Bryan
# 976           San Diego
# 977                Reno
# 978           Knoxville
# 979         Baton Rouge
# 980               Boise
# 981           Bradenton
# 982            Honolulu
# 983         Punta Gorda
# 984      Salt Lake City
# 985             Yonkers
# 986             Concord
# 987           Vancouver
# 988             Fontana
# 989          Shreveport
# 990             Killeen
# 991          Fort Worth
# 992        Murfreesboro
# 993           Vancouver
# 994            Hesperia
# 995             Lubbock
# 996        Palm Springs
# 997                Reno
# 998           Elk Grove
# 999            Pasadena
# 1000           Columbia
# 1001             Fresno
# 1002         Portsmouth
# 1003             Marina
# 1004             Denver
# 1005          Bradenton
# 1006            Bel Air
# 1007             Corona
# 1008             Boston
# 1009        Clarksville
# 1010              Hemet
# 1154             Naples
# 1155          Roseville
# 1156             Orange
# 1157       Murfreesboro
# 1158        Santa Maria
# 1159         South Bend
# 1160         Clearwater
# 1161       Newport News
# 1162          Hollywood
# 1163              Fargo
# 1164             Eugene
# 1165      Daytona Beach
# 1166             Newark
# 1167              Akron
# 1168             Lorain
# 1169        Bloomington
# 1170   Round Lake Beach
# 1171          Santa Ana
# 1172         Huntington
# 1173           Monterey
# 1174        New Orleans
# 1175           San Jose
# 1176      Clarke County
# 1177    Davidson County
# 1178       Myrtle Beach
# 1179           Mesquite
# 1180        Kansas City
# 1181       Winter Haven
# 1182           Columbia
# 1183      Clarke County
# 1184          San Diego
# 1185             Corona
# 1186            Hialeah
# 1187     Port St. Lucie
# 1188       Fort Collins
# 1189         Pittsburgh
# 1190       Poughkeepsie
# 1191           San Jose
# 1192            Lansing
# 1193        Panama City
# 1194          Fitchburg
# 1195             Odessa
# 1196              Hemet
# 1197         Tuscaloosa
# 1198        Port Arthur
# 1199            Madison
# 1200         Naperville
# 1201           New York
# 1202         Louisville
# 1203      San Francisco
# 1204        Chula Vista
# 1205           Hesperia
# 1206      Thousand Oaks
# 1207            Trenton
# 1208        New Bedford
# 1209            Danbury
# 1210   West Valley City
# 1211             Mobile
# 1212             Laredo
# 1213         Leominster
# 1214     St. Petersburg
# 1215           Appleton
# 1216            Memphis
# 1217            Hickory
# 1218             Denton
# 1219             Lorain
# 1220             Toledo
# 1221            Spokane
# 1222            Trenton
# 1223       Garden Grove
# 1224              Houma
# 1225            Fontana
# 1226            Trenton
# 1227           SQL City

# %% [markdown]
# ### Entity Relationship Diagram (Optional)
#
# After doing some detective work and finding the tables in the Police Department database, you discover that there is an ERD! This can be really helpful in your quest to find the murderer. If you like, challenge yourself (and your SQL skills) to continue on by just querying the `information_schema` as needed. Otherwise, you can click the dropdown below to reveal the ERD to help you see the tables and relationships in the Police Department database at a glance:
#
# <details>
#   <summary>Check the SQL Murder Mystery ERD</summary>
#   <img src="https://github.com/freestackinitiative/coop_sql_notebooks/blob/main/assets/murder_mystery_schema.png?raw=1" alt="ERD for SQL Murder Mystery"/>
# </details>

# %% [markdown]
# ### Diagrama de Relaciones de Entidad (Opcional)
#
# Después de hacer un poco de trabajo de detective y encontrar las tablas en la base de datos del Departamento de Policía, descubres que hay un ERD (Diagrama de Relaciones de Entidad). Esto puede ser realmente útil en tu búsqueda para encontrar al asesino. Si lo prefieres, desafíate a ti mismo (y tus habilidades en SQL) a continuar solo consultando el `information_schema` según sea necesario. De lo contrario, puedes hacer clic en el desplegable a continuación para revelar el ERD que te ayudará a ver las tablas y las relaciones en la base de datos del Departamento de Policía de un vistazo:
#
# <details>
#   <summary>Revisa el ERD del SQL Murder Mystery</summary>
#   <img src="https://github.com/freestackinitiative/coop_sql_notebooks/blob/main/assets/murder_mystery_schema.png?raw=1" alt="ERD for SQL Murder Mystery"/>
# </details>

# %%
# %%sql
# SELECT *
# FROM crime_scene_report
# WHERE type='murder' AND date=20180115
# Out:
#        date    type  \
# 0  20180115  murder
# 1  20180115  murder
# 2  20180115  murder
#
#                                                                                           description  \
# 0                                                                   Life? Dont talk to me about life.
# 1                                                 Mama, I killed a man, put a gun against his head...
# 2  Security footage shows that there were 2 witnesses. The first witness lives at the last house o...
#
#        city
# 0    Albany
# 1      Reno
# 2  SQL City
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('description').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('city').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'date'}, axis=1)
#               .sort_values('date', ascending=True))
#   xs = counted['date']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('description')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='description', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'date'}, axis=1)
#               .sort_values('date', ascending=True))
#   xs = counted['date']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_3.sort_values('date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('city')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='city', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('date')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['city'].value_counts()
#     for x_label, grp in _df_4.groupby('description')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('description')
# _ = plt.ylabel('city')

# %% [markdown]
# ___

# %% [markdown]
# ## Resolviendo el Misterio (y verificando si resolviste el caso)
#
# De aquí en adelante, usarás tus habilidades y las pistas en la base de datos del Departamento de Policía para encontrar al asesino. Cuando creas que has encontrado al asesino, vuelve a esta sección y usa la celda de abajo para verificar tu respuesta y ver si encontraste al asesino:
#
# ejemplo:
# ```python
# check_suspect("Adam Levine")
# ```

# %%
check_suspect("Jeremy Bowers")
# Out:
# Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge,try querying the interview transcript of the murderer to find the real villain behind this crime.If you feel especially confident in your SQL skills, try to complete this final step with no more than 2 queries.
# Use this same `check_suspect` function with your new suspect to check your answer.
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Espacio de Trabajo
#
# Usa las celdas de abajo para escribir tus consultas y trabajar en resolver el misterio. Cuando tengas un sospechoso, verifica tu respuesta usando la [celda arriba de esta](#solving-the-mystery-and-checking-if-you-cracked-the-case) y ejecuta su nombre a través de la función `check_suspect`. Si encuentras al asesino, la función te lo dirá.
#
# No olvides usar `%%sql` en la parte superior de las celdas de `Code` que crees para que tus consultas SQL funcionen. ¡Buena suerte, detectives!

# %%
# %%sql
# SELECT *
# FROM crime_scene_report
# WHERE type='murder' AND date=20180115
# Out:
#        date    type  \
# 0  20180115  murder
# 1  20180115  murder
# 2  20180115  murder
#
#                                                                                           description  \
# 0                                                                   Life? Dont talk to me about life.
# 1                                                 Mama, I killed a man, put a gun against his head...
# 2  Security footage shows that there were 2 witnesses. The first witness lives at the last house o...
#
#        city
# 0    Albany
# 1      Reno
# 2  SQL City

# %% [markdown]
# Primera busqueda con los datos dados, en la tabla de crimen_scene_report ubicamos  un asesinato ocurrido el dia 15 de enero de 2018 en SQL city.

# %%
# %%sql
# SELECT id, name,address_street_name
# FROM person
# WHERE name LIKE 'Annabel%' AND address_street_name= 'Franklin Ave'
# Out:
#       id            name address_street_name
# 0  16371  Annabel Miller        Franklin Ave

# %% [markdown]
# Obtenemos el id de Annabel y asi podremos consular lo que ella vio.

# %%
# %%sql
# SELECT transcript
# FROM interview
# WHERE person_id=16371
# Out:
#                                                                                            transcript
# 0  I saw the murder happen, and I recognized the killer from my gym when I was working out last we...

# %% [markdown]
# Con el id de Annabel podemos obtener su testimonio del dia, ella vio el asesinato y reconoció al asesino en su gimnasio cuando estaba haciendo ejercicio la semana pasada, el 9 de enero.

# 40  40760          Renata Faver      976650             745     Northwestern Dr  547572040
# 41  10010             Muoi Cary      385336             741     Northwestern Dr  828638512
# 42  39688            Abe Roeker      537445             689     Northwestern Dr  438969447
# 43  26758      Angelena Billman      942074             629     Northwestern Dr  341854756
# 44  75484          Del Tacderen      447887             607     Northwestern Dr  243821337
# 45  12711        Norman Apolito      667757             599     Northwestern Dr  778264744
# 46  85280             Donn Duin      569122             540     Northwestern Dr  613873810
# 47  40336       Fredia Billeter      251082             404     Northwestern Dr  108056488
# 48  15171          Weldon Penso      336999             311     Northwestern Dr  131379495
# 49  89906       Kinsey Erickson      510019             309     Northwestern Dr  635287661

# %% [markdown]
# Consultando a una persona que viva en Northwestern y ordernardo descendente el numero de la casas, puedo saber quien vive en la ultima casa y voy a revisar con el id si tiene en la tabla interview algo que haya dicho.
# 0	14887	Morty Schapiro	118009	4919	Northwestern Dr	111564949

# %%
# %%sql
# SELECT transcript
# FROM interview
# WHERE person_id=14887
# Out:
#                                                                                            transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership nu...

# %% [markdown]
# Con esra consulta de Morty su interview dice:  Tenía una bolsa de "Get Fit Now Gym". El número de membresía en la bolsa comenzaba con "48Z". Sólo los miembros de oro tienen esas bolsas. El hombre se subió a un coche con una placa que decía "H42W".

# %%
# %%sql
# SELECT dri.id, dri.plate_number, per.name, per.address_street_name
# FROM drivers_license dri
# JOIN person per ON dri.id= per.license_id
# WHERE dri.plate_number LIKE 'H42W%'
# Out:
#        id plate_number            name address_street_name
# 0  183779       H42W0X  Maxine Whitely             Fisk Rd

# %% [markdown]
# Consultando 2 tablas , usando el JOIN, pude consultar y obtener los datos de la patente H42W y asi obtener el nombre de la persona con su id.

# %%
# %%sql
# SELECT *
# FROM get_fit_now_check_in
# WHERE membership_id LIKE '48Z%'AND check_in_date=20180109
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %% [markdown]
# Consultando la membresia que dijo el testigo con la fecha vista por la otra persona, me arroja 2 personas que son sospechosas.

# %%
# %%sql
# SELECT *
# FROM get_fit_now_member get
# JOIN get_fit_now_check_in  get_check ON get.id= get_check.membership_id
# WHERE get_check.membership_id IN('48Z7A', '48Z55')
# Out:
#       id  person_id           name  membership_start_date membership_status membership_id  \
# 0  48Z7A      28819   Joe Germuska               20160305              gold         48Z7A
# 1  48Z55      67318  Jeremy Bowers               20160101              gold         48Z55
#
#    check_in_date  check_in_time  check_out_time
# 0       20180109           1600            1730
# 1       20180109           1530            1700

# %% [markdown]
# Aqui puedo ver mas detallado que membresia tiene, para dar con el culpable.

# %%
# %%sql
# SELECT *
# FROM facebook_event_checkin face
# JOIN person per ON face.person_id= per.id
# WHERE per.id IN ('28819','67318')
# Out:
#    person_id  event_id              event_name      date     id           name  license_id  \
# 0      67318      4719  The Funky Grooves Tour  20180115  67318  Jeremy Bowers      423327
# 1      67318      1143    SQL Symphony Concert  20171206  67318  Jeremy Bowers      423327
#
#    address_number    address_street_name        ssn
# 0             530  Washington Pl, Apt 3A  871539279
# 1             530  Washington Pl, Apt 3A  871539279

# %% [markdown]
# En esta consulta me indica que solo Jeremy Bowers tiene evento en su face el dia 15.01.2018, el dia del asesinado. No hay nada de Joe Germuska.

# %%
# %%sql
# SELECT transcript
# FROM interview
# WHERE person_id=67318
# Out:
#                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" ...

# %% [markdown]
# El es el asesino, pero fue contratado. Dio detalles de quien le pago.

# %%
# %%sql
# SELECT *
# FROM facebook_event_checkin
# WHERE event_name= 'SQL Symphony Concert' And date BETWEEN 20171201 AND 20171231
# ORDER BY person_id ASC
# Out:
#     person_id  event_id            event_name      date
# 0       11173      1143  SQL Symphony Concert  20171223
# 1       19260      1143  SQL Symphony Concert  20171214
# 2       19292      1143  SQL Symphony Concert  20171213
# 3       24397      1143  SQL Symphony Concert  20171208
# 4       24556      1143  SQL Symphony Concert  20171207
# 5       24556      1143  SQL Symphony Concert  20171221
# 6       24556      1143  SQL Symphony Concert  20171224
# 7       28582      1143  SQL Symphony Concert  20171220
# 8       28582      1143  SQL Symphony Concert  20171215
# 9       43366      1143  SQL Symphony Concert  20171207
# 10      58898      1143  SQL Symphony Concert  20171220
# 11      62596      1143  SQL Symphony Concert  20171225
# 12      67318      1143  SQL Symphony Concert  20171206
# 13      69325      1143  SQL Symphony Concert  20171206
# 14      69699      1143  SQL Symphony Concert  20171214
# 15      79312      1143  SQL Symphony Concert  20171203
# 16      81526      1143  SQL Symphony Concert  20171202
# 17      92343      1143  SQL Symphony Concert  20171212
# 18      99716      1143  SQL Symphony Concert  20171206
# 19      99716      1143  SQL Symphony Concert  20171212
# 20      99716      1143  SQL Symphony Concert  20171229

# %% [markdown]
# Aqui tengo a 2 personas que asistieron 3 veces en diciembre a ese concierto. Tengo el person_id para seguir indagando.

# %%
# %%sql
# SELECT *
# FROM person
# WHERE id IN( '24556' , '99716')
# Out:
#       id              name  license_id  address_number address_street_name        ssn
# 0  24556       Bryan Pardo      101191             703          Machine Ln  816663882
# 1  99716  Miranda Priestly      202298            1883          Golden Ave  987756388

# %% [markdown]
# EL asesino dijo que era una mujer y la unica mujer es Miranda Priestly

# %%
# %%sql
# SELECT id, hair_color,height, plate_number,car_make, car_model
# FROM drivers_license
# WHERE id= '202298'
# Out:
#        id hair_color  height plate_number car_make car_model
# 0  202298        red      66       500123    Tesla   Model S

# %% [markdown]
# Aqui se puede decir que ella tiene la altura informada y el carro que dijo el asesino.

# %%
# %%sql
# SELECT *
# FROM get_fit_now_member get
# JOIN get_fit_now_check_in get_check ON get.id= get_check.membership_id
# WHERE get.id= '202298'
# Out:
# Empty DataFrame
# Columns: [id, person_id, name, membership_start_date, membership_status, membership_id, check_in_date, check_in_time, check_out_time]
# Index: []

# %%
# %%sql
# SELECT *
# FROM income
# WHERE ssn=987756388
# Out:
#          ssn  annual_income
# 0  987756388         310000

# %% [markdown]
# No hay nada
